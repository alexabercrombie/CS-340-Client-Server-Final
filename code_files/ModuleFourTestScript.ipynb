# %%
# Python Testing Script

#TODO: import for your CRUD module

from CRUD_Python_Module import AnimalShelter

#TODO: Instantiate an instance of your class

UserSearch = AnimalShelter()

CujoData  = {
    "name" : "Cujo",
    "age_upon_outcome" : "5 years",
    "breed" : "St Bernard Demon Mix",
    "date_of_birth" : "2021-05-31",
    "outcome_type" : "Transfer",
    "sex_upon_outcome" : "Unknown"
}
    
#TODO: Use your create function create a new record in the aac database

UserSearch.create(CujoData)

#TODO: Use your read funtion to return records from the aac database

CujoQuery = {"name" : "Cujo", "breed" : "St Bernard Demon Mix"}

UserSearch.read(CujoQuery)
# Out:
# [{'_id': ObjectId('6a1d1ffec355941d14d3d42e'),
#   'name': 'Cujo',
#   'age_upon_outcome': '5 years',
#   'breed': 'St Bernard Demon Mix',
#   'date_of_birth': '2021-05-31',
#   'outcome_type': 'Transfer',
#   'sex_upon_outcome': 'Unknown'}]
